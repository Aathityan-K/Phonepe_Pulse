# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# Cloning into 'pulse'...
# remote: Enumerating objects: 7975, done.
# remote: Counting objects: 100% (7975/7975), done.
# remote: Compressing objects: 100% (6637/6637), done.
# remote: Total 7975 (delta 2465), reused 6527 (delta 1031), pack-reused 0
# Receiving objects: 100% (7975/7975), 2.11 MiB | 12.20 MiB/s, done.
# Resolving deltas: 100% (2465/2465), done.

# %%
import pandas as pd
import json
import os

# %% [markdown]
# Creating an empty dictionary to store the extracted data: The "dict1" dictionary is created to store the extracted transaction data, and it contains keys for "State", "Year", "Quarter", "Transaction_type", "Transaction_count", and "Transaction_amount".

# %%
path="/content/pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Transacion_type':[], 'Transacion_count':[], 'Transacion_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/" #travels between the state folder
    Agg_yr=os.listdir(p_i) #gets the years from each state folder  
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transacion_type'].append(Name)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json'))) #name of the json file
#Succesfully created a dataframe
pd.DataFrame(clm)
# Out:
#                                    State  Year  Quater  \
# 0                                mizoram  2022       1
# 1                                mizoram  2022       1
# 2                                mizoram  2022       1
# 3                                mizoram  2022       1
# 4                                mizoram  2022       1
# ...                                  ...   ...     ...
# 3589  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 3590  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 3591  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 3592  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 3593  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
#
#                Transacion_type  Transacion_count  Transacion_amount
# 0        Peer-to-peer payments            302740       1.691281e+09
# 1     Recharge & bill payments            190137       7.654106e+07
# 2            Merchant payments            109669       1.741577e+08
# ...

# %%
agg_transaction = pd.DataFrame(clm)
agg_transaction.head()
agg_transaction.to_csv("agg_transaction.csv", index=False)

# %%
path="/content/pulse/data/aggregated/user/country/india/state/"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'User_brand':[], 'User_count':[], 'User_percentage':[]}
for i in Agg_state_list:
    p_i=path+i+"/" #travels between the state folder
    Agg_yr=os.listdir(p_i) #gets the years from each state folder  
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            try:
              for user in D['data']['usersByDevice']:
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quater'].append(int(k.strip('.json')))
                clm['User_brand'].append(user['brand'])
                clm['User_count'].append(user['count'])
                clm['User_percentage'].append(user['percentage'])
            except:
              continue
pd.DataFrame(clm)
# Out:
#                                    State  Year  Quater User_brand  User_count  \
# 0                                mizoram  2022       1     Xiaomi       35679
# 1                                mizoram  2022       1       Vivo       23611
# 2                                mizoram  2022       1       Oppo       14866
# 3                                mizoram  2022       1    Samsung       14652
# 4                                mizoram  2022       1     Realme        8423
# ...                                  ...   ...     ...        ...         ...
# 6727  dadra-&-nagar-haveli-&-daman-&-diu  2021       2     Huawei        4834
# 6728  dadra-&-nagar-haveli-&-daman-&-diu  2021       2   Motorola        4803
# 6729  dadra-&-nagar-haveli-&-daman-&-diu  2021       2      Tecno        4453
# 6730  dadra-&-nagar-haveli-&-daman-&-diu  2021       2     Lenovo        4280
# 6731  dadra-&-nagar-haveli-&-daman-&-diu  2021       2     Others       27481
#
#       User_percentage
# ...

# %%
agg_user = pd.DataFrame(clm)
agg_user.head()
agg_user.to_csv("agg_user.csv", index=False)

# %%
path="/content/pulse/data/map/transaction/hover/country/india/state/"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'District':[], 'Transaction_count':[], 'Transaction_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/" 
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['District'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
pd.DataFrame(clm)
# Out:
#                                     State  Year  Quater  \
# 0                                 mizoram  2022       1
# 1                                 mizoram  2022       1
# 2                                 mizoram  2022       1
# 3                                 mizoram  2022       1
# 4                                 mizoram  2022       1
# ...                                   ...   ...     ...
# 14631  dadra-&-nagar-haveli-&-daman-&-diu  2021       4
# 14632  dadra-&-nagar-haveli-&-daman-&-diu  2021       4
# 14633  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 14634  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 14635  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
#
#                               District  Transaction_count  Transaction_amount
# 0                    serchhip district              25542        7.357750e+07
# 1                      aizawl district             341192        1.081700e+09
# ...

# %%
map_transaction = pd.DataFrame(clm)
map_transaction.head()
map_transaction.to_csv("map_transaction.csv", index=False)

# %%
path="/content/pulse/data/map/user/hover/country/india/state/"
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'District':[], 'User_count':[]}
for i in Agg_state_list:
    p_i=path+i+"/" 
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            district_data = D['data']['hoverData']
            for district, info in district_data.items():
              clm['District'].append(district)
              clm['User_count'].append(info['registeredUsers'])
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
              
pd.DataFrame(clm)
# Out:
#                                     State  Year  Quater  \
# 0                                 mizoram  2022       1
# 1                                 mizoram  2022       1
# 2                                 mizoram  2022       1
# 3                                 mizoram  2022       1
# 4                                 mizoram  2022       1
# ...                                   ...   ...     ...
# 14635  dadra-&-nagar-haveli-&-daman-&-diu  2021       4
# 14636  dadra-&-nagar-haveli-&-daman-&-diu  2021       4
# 14637  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 14638  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 14639  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
#
#                               District  User_count
# 0                    serchhip district        4906
# 1                      aizawl district       59433
# 2                     lunglei district       14538
# 3                       mamit district        6299
# ...

# %%
map_user = pd.DataFrame(clm)
map_user.head()
map_user.to_csv("map_user.csv", index=False)

# %%
path = '/content/pulse/data/top/transaction/country/india/state/'
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Entity_Name':[], 'Transacion_count':[], 'Transacion_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/" #travels between the state folder
    Agg_yr=os.listdir(p_i) #gets the years from each state folder  
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
              Name = z['entityName']
              count = z['metric']['count']
              amount = z['metric']['amount']
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
              clm['Entity_Name'].append(Name)
              clm['Transacion_count'].append(count)
              clm['Transacion_amount'].append(amount)
pd.DataFrame(clm)
# Out:
#                                    State  Year  Quater  \
# 0                                mizoram  2022       1
# 1                                mizoram  2022       1
# 2                                mizoram  2022       1
# 3                                mizoram  2022       1
# 4                                mizoram  2022       1
# ...                                  ...   ...     ...
# 5915  dadra-&-nagar-haveli-&-daman-&-diu  2021       4
# 5916  dadra-&-nagar-haveli-&-daman-&-diu  2021       4
# 5917  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 5918  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 5919  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
#
#                  Entity_Name  Transacion_count  Transacion_amount
# 0                     aizawl            341192       1.081700e+09
# 1                    lunglei             70118       2.257623e+08
# 2                  lawngtlai             52546       1.777109e+08
# ...

# %%
top_transaction = pd.DataFrame(clm)
top_transaction.head()
top_transaction.to_csv("top_transaction.csv", index=False)

# %%
path = '/content/pulse/data/top/user/country/india/state/'
Agg_state_list=os.listdir(path)

clm={'State':[], 'Year':[],'Quater':[],'Entity_Name':[], 'Registered_users':[]}
for i in Agg_state_list:
    p_i=path+i+"/" #travels between the state folder
    Agg_yr=os.listdir(p_i) #gets the years from each state folder  
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)        
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
              Name = z['name']
              count = z['registeredUsers']
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
              clm['Entity_Name'].append(Name)
              clm['Registered_users'].append(count)
pd.DataFrame(clm)
# Out:
#                                    State  Year  Quater  \
# 0                                mizoram  2022       1
# 1                                mizoram  2022       1
# 2                                mizoram  2022       1
# 3                                mizoram  2022       1
# 4                                mizoram  2022       1
# ...                                  ...   ...     ...
# 5915  dadra-&-nagar-haveli-&-daman-&-diu  2021       4
# 5916  dadra-&-nagar-haveli-&-daman-&-diu  2021       4
# 5917  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 5918  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
# 5919  dadra-&-nagar-haveli-&-daman-&-diu  2021       2
#
#                  Entity_Name  Registered_users
# 0                     aizawl             59433
# 1                    lunglei             14538
# 2                  lawngtlai             11459
# 3                    kolasib              8375
# 4                   champhai              6875
# ...

# %%
top_user = pd.DataFrame(clm)
top_user.head()
top_user.to_csv("top_user.csv", index=False)
